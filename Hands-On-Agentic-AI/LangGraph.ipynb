# %% [markdown]
# ### Vanilla
# ```
# input ➡️ LLM ➡️ output
# ```

# %%
# one chatgpt example

# %%
# one splinter example

# %%
# one something else (image gen?)

# %%
# encapsulate in function (make it compatible with langgraph)

# %% [markdown]
# ### Chaining
# ```
# input ➡️ LLM1 ➡️ LLM2 ➡️ LLM3 ➡️ output
# ```

# %%
# hardcoded example goes here - 3 subsequent calls to do something simple, better than doing it immediatelly

# %%
# hardcoded example rewritten as langgraph

# %% [markdown]
# ### Agentic
# ```
#                   ↗️ LLM2 ➡️ LLM3 ↘️
# input ➡️ LLM1 🔀                     🔀 LLM5 ➡️ output
#                   ↘️ LLM4 🔄🔄🔄 ↗️
# ```

# %%
# only in langgraph - some cool example

# %% [markdown]
# ### Your agents go here

# %% [markdown]
# FYI: we prepared some simple nodes for you to include if you'd like.

# %%
# stub code
