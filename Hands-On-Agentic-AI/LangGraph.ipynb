# %% [markdown]
# ### Vanilla
# ```
# input ➡️ LLM ➡️ output
# ```

# %%
from openai import OpenAI
import dotenv
dotenv.load_dotenv()
import os
import base64
from IPython.display import Markdown, display

# %% [markdown]
# ##### LLM example 1
# This goes to openai servers

# %%
client_oai = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
response = client_oai.chat.completions.create(
    model="gpt-5-mini",
    messages=[{"role": "user", "content": "Write a short example abstract for a scientific paper. Respond with only the abstract."}]
)
response.choices[0].message.content
# Out:
# 'Workplace stress contributes to reduced productivity and poor health, but scalable interventions with demonstrated physiological effects remain limited. We conducted a randomized controlled trial to assess the efficacy of an eight-week mindfulness-based stress reduction (MBSR) program in reducing perceived stress and physiological stress markers among office workers. One hundred fifty participants were randomized to MBSR (n = 75) or wait-list control (n = 75). Primary outcome was change in Perceived Stress Scale (PSS) score at 8 weeks; secondary outcomes included salivary cortisol, sleep quality, and work engagement, assessed at baseline, 8 weeks, and 3-month follow-up. At 8 weeks, the MBSR group showed greater reduction in PSS (mean change −7.2 ± 4.1) than control (−2.1 ± 3.5), with a between-group difference of −5.1 (95% CI −6.8 to −3.4; p < 0.001). Salivary cortisol declined by 15% in the MBSR group versus 3% in controls (p = 0.02). Improvements in sleep quality and work engagement paralleled reductions in stress and were maintained at 3 months. These findings indicate that MBSR is an effective, durable intervention for reducing both perceived and physiological stress in the workplace.'

# %% [markdown]
# ##### LLM example 2
# This goes to Splinter

# %%
client_splinter = OpenAI(
    base_url="https://llm.science.ai.cam.ac.uk",
    api_key=os.getenv("SPLINTER_API_KEY")
)
response = client_splinter.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": "Write a short example abstract for a scientific paper. Respond with only the abstract."}]
)
response.choices[0].message.content
# Out:
# '**Abstract**  \nWe investigated the efficacy of a novel photo‑responsive polymeric hydrogel for on‑demand drug release in vivo. The hydrogel, synthesized by copolymerizing methacrylated gelatin with a spiropyran‑based crosslinker, exhibits reversible stiffness modulation upon exposure to 530\u202fnm green light (ΔG′\u202f≈\u202f3‑fold). In vitro release profiles of dexamethasone (1\u202fµM) demonstrated a light‑triggered burst release (71\u202f±\u202f4\u202f% within 10\u202fmin) followed by sustained diffusion over 48\u202fh, whereas dark controls released only 12\u202f±\u202f2\u202f% over the same period. Subcutaneous implantation in murine dorsal skin showed that a single 30‑second illumination event reduced local inflammation by 58\u202f±\u202f5\u202f% (p\u202f<\u202f0.01) relative to non‑illuminated hydrogels, as assessed by histological scoring and cytokine quantification. Finite‑element modeling corroborated the experimental findings, indicating that light‑induced network relaxation enhances mesh size and drug diffusivity without compromising biocompatibility. Our results establish a versatile platform for spatiotemporal control of therapeutic delivery, offering potential applications in precision medicine and minimally invasive treatment regimens.'

# %% [markdown]
# We also have other models, for:
#
# - Reasoning
# - Vision
# - Image Generation
# - Image Editing
# - Text to Speech
# - Speech to Text
# - Embeddings
#
# See `example-calls.ipynb` for details!

# %%
from agents import ocr
prompt = "Here is some handwritten text and equations in an image. Please read it and convert to markdown, rendering the equations in LaTeX format."
image_path = 'data/imgs/curie.jpg'
response = ocr.ocr(image_path, prompt)
display(Markdown(response))
# Out:
# 24 mars 1907
#
# La mesure de la lancette L fait voir que le rayonnement $\alpha$ a passé de $167$ à $528 \text{ gr.}^{2}$ en 42 jours, et que le rayonnement $\beta$ n'a pas varié. Donc RaE est resté avec RaD lors de l'extraction de Po.
#
# En examinant la courbe d'accroissement de Po dans RaD+RaE, on voit qu'un accroissement si rapide correspond au début de la courbe — pour laquelle
#
# $\frac{\rho}{\rho_{max.}} = \frac{\lambda'}{\lambda'-\lambda} e^{-\lambda t}$
#
# Or depuis du minimum :
#
# $e^{-\lambda t} = \begin{cases}
# 0.49 \\
# 0.913
# \end{cases}$
#
# Lorsqu'on a trouvé:
#
# Soit $t_1$, le temps pour $167 \text{ ggr.}^2$
# $t_2$, " ", " $528 \text{ ggr.}^2$
#
# $t_2 - t_1 = 12 \text{ jours}$ $\frac{t_2}{t_1} = \frac{528}{167} = 3,16$
#
# d'où $3,16 t_1 = 12$
# $t_1 = 5,5 \text{ j.}$
#
# Au temps $t_1$, le rayon $\alpha$ dans Sol. S₁ a été évalué à $700 \text{ E.S.}$. Donc
#
# $\frac{700}{\alpha_{max.}} = \frac{5,5+1}{0,913 \times 200} \Rightarrow 200$
#
# $\alpha_{max.} = \frac{700 \times 200 \times 0,913}{5,5} = 23200 \text{ E.S.}$
#
# L'accroissement est donc conforme, comme ordre de grandeur à la proportion que le polonium a été extrait de la solution S₁. Or on n'a recueilli que $2500 \text{ E.S.}$ sur la lame. On s'attendrait à trouver
#
# la fraction $\frac{8}{9} = 0,9$ de la quantité maximale, c'est-à-dire une qualité de l'ordre de $20000 \text{ E.S.}$.

# %% [markdown]
# ### Chaining
# ```
# input ➡️ LLM1 ➡️ LLM2 ➡️ LLM3 ➡️ output
# ```

# %%
from agents import ocr
prompt = "Here is some handwritten text and equations in an image. Please read it and convert to markdown, rendering the equations in LaTeX format."
image_path = 'data/imgs/curie.jpg'
response1 = ocr.ocr(image_path, prompt)

# %%
# display(Markdown(response1))

# %%
response2 = client_splinter.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": f"Translate the following to English: {response1}. Respond with only the content, in valid markdown, in english."}]
).choices[0].message.content

# %%
# display(Markdown(response2))

# %%
response3 = client_splinter.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": f"Briefly explain the general context and the topic that these notes are discussing: {response2}. Answer what the area is, who the likely author is, when was it written. Make notes on likely mistakes introduced by OCR."}]
).choices[0].message.content

# %%
# display(Markdown(response3))

# %%
response4 = client_splinter.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": f"Explain some physics notes line by line to someone with basic physics knowledge. Format it as markdown, explaining all sentences. The context is: {response3}. The notes are: {response2}"}]
).choices[0].message.content

# %%
# display(Markdown(response4))

# %%
response5 = client_splinter.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": f"Summarise the following to write succinct 2 paragraphs explaining what the notes are about, to someone with a basic physics knowledge. Include important details: {response4}"}]
).choices[0].message.content

# %%
display(Markdown(response5))
# Out:
# The notebook entry records a decay‑chain experiment carried out on 24 March 1987 in which the growth of α‑activity from the ^210Po daughter was used to monitor the chemical extraction of its parent ^210Pb from a radium‑226 source.  An “L‑probe” proportional counter measured the α‑count rate, which rose from 1.67 × 10⁷ to 5.28 × 10⁷ counts in 42 days while the β‑count (from the ^210Bi intermediate) stayed constant; this indicated that radon (^222Rn) escaped but lead remained in solution.  The author fitted the early‑time part of the standard parent‑daughter growth law
#
# \[
# \frac{P(t)}{P_{\max}}=\frac{\lambda'}{\lambda'-\lambda}\bigl(e^{-\lambda t}-e^{-\lambda' t}\bigr)
# \]
#
# to the data, defining two measurement times \(t_{1}\) (α‑rate = 1.67 × 10⁷) and \(t_{2}\) (α‑rate = 5.28 × 10⁷).  From the recorded difference (12 d) and ratio (\(t_{2}/t_{1}=3.16\)) they obtained \(t_{1}=5.5\) d and \(t_{2}\approx17.5\) d.  Converting the α‑rate at \(t_{1}\) to the laboratory’s calibrated unit (700 E.S., “equivalent seconds”) and inserting the detector efficiency (0.913) and geometry factor (200) into the rearranged growth equation gave a theoretical maximum activity \(a_{\max}\approx2.3\times10^{4}\) E.S.
#
# Comparing this ceiling with the actual activity recovered from the source (2 800 E.S.) showed that only about 12 % of the possible ^210Po was obtained, far below the ≈ 89 % (8/9) yield that the researcher had anticipated based on earlier separations.  The discrepancy highlighted a loss of roughly 2 000 E.S. and pointed to inefficiencies in the Pb‑210/Po‑210 chemical extraction step that would need to be improved in subsequent runs.  In short, the notes document the kinetic analysis of a parent‑daughter decay chain, the extraction test for ^210Pb, and a quantitative consistency check that revealed a much lower-than‑expected recovery of the α‑emitting daughter.

# %% [markdown]
# ### Agentic
# ```
#                   ↗️ LLM2 ➡️ LLM3 ↘️
# input ➡️ LLM1 🔀                     🔀 LLM5 ➡️ output
#                   ↘️ LLM4 🔄🔄🔄 ↗️
# ```

# %%
# only in langgraph - some cool example

# %% [markdown]
# ### Your agents go here

# %% [markdown]
# FYI: we prepared some simple nodes for you to include if you'd like.

# %%
# stub code
